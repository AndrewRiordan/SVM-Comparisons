# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv('voice.csv')
#add a bias term
data['dummy'] = 1
data['label'].replace({'male': -1, 'female': 1},inplace=True)

# %%
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...   meanfun    minfun    maxfun  \
# 0   274.402906  0.893369  0.491918  ...  0.084279  0.015702  0.275862
# 1   634.613855  0.892193  0.513724  ...  0.107937  0.015826  0.250000
# 2  1024.927705  0.846389  0.478905  ...  0.098706  0.015656  0.271186
# 3     4.177296  0.963322  0.727232  ...  0.088965  0.017798  0.250000
# 4     4.333713  0.971955  0.783568  ...  0.106398  0.016931  0.266667
#
#     meandom    mindom    maxdom   dfrange   modindx  label  dummy
# 0  0.007812  0.007812  0.007812  0.000000  0.000000     -1      1
# 1  0.009014  0.007812  0.054688  0.046875  0.052632     -1      1
# 2  0.007990  0.007812  0.015625  0.007812  0.046512     -1      1
# 3  0.201497  0.007812  0.562500  0.554688  0.247119     -1      1
# 4  0.712812  0.007812  5.484375  5.476562  0.208274     -1      1
#
# [5 rows x 22 columns]

# %%
data.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  ...  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000  ...
# mean      0.084309     3.140168    36.568461     0.895127     0.408216  ...
# std       0.042783     4.240529   134.928661     0.044980     0.177521  ...
# min       0.014558     0.141735     2.068455     0.738651     0.036876  ...
# 25%       0.042560     1.649569     5.669547     0.861811     0.258041  ...
# 50%       0.094280     2.197101     8.318463     0.901767     0.396335  ...
# 75%       0.114175     2.931694    13.648905     0.928713     0.533676  ...
# max       0.252225    34.725453  1309.612887     0.981997     0.842936  ...
#
#            meanfun       minfun       maxfun      meandom       mindom  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.142807     0.036802     0.258842     0.829211     0.052647
# std       0.032304     0.019220     0.030077     0.525205     0.063299
# min       0.055565     0.009775     0.103093     0.007812     0.004883
# 25%       0.116998     0.018223     0.253968     0.419828     0.007812
# 50%       0.140519     0.046110     0.271186     0.765795     0.023438
# 75%       0.169581     0.047904     0.277457     1.177166     0.070312
# max       0.237636     0.204082     0.279114     2.957682     0.458984
#
#             maxdom      dfrange      modindx        label   dummy
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.0
# mean      5.047277     4.994630     0.173752     0.000000     1.0
# std       3.521157     3.520039     0.119454     1.000158     0.0
# min       0.007812     0.000000     0.000000    -1.000000     1.0
# 25%       2.070312     2.044922     0.099766    -1.000000     1.0
# 50%       4.992188     4.945312     0.139357     0.000000     1.0
# 75%       7.007812     6.992188     0.209183     1.000000     1.0
# max      21.867188    21.843750     0.932374     1.000000     1.0
#
# [8 rows x 22 columns]

# %%
y = data.pop('label')
X = data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)  # Don't cheat - fit only on training data
X_train = scaler.transform(X)

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty="l1", max_iter=4000000)
clf.fit(X_train, y)
clf.coef_
# Out:
# array([[ 0.        , -0.30566538,  0.2209283 ,  0.        , -0.00617697,
#         -1.31033147,  0.        ,  0.70951584, -1.12831588,  1.60349652,
#         -0.46384461,  0.        ,  4.27375269, -0.6124212 ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.37358161,
#          0.        ]])

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty="l1", max_iter=4000001)
clf.fit(X_train, y)
clf.coef_
# Out:
# array([[ 0.        , -0.08212448,  0.05167075,  0.        ,  0.        ,
#         -1.2044968 ,  0.        ,  0.62846098, -1.42856208,  1.64310457,
#         -0.11791645,  0.        ,  4.65606129, -0.46325769,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.19628668,
#          0.        ]])

# %%
#Tried to establish a baseline for correctness but it doesn't look like the svm if converging
#for this dataset

# %%
print(X.shape)
# Out:
# (3168, 21)

# %%
import math
def dual_coord_l1(X, y, max_steps, C=.25):
    u=C
    n_features = X.shape[1]
    n_samples = X.shape[0]
    w = np.zeros(n_features)
    alpha = np.zeros(n_samples)
    for o in range(max_steps) : #outer iteration
        for i in range(X.shape[0]): #inner iteration
            #step a
            G = y[i]*w.dot(X[i])-1+alpha[i] * 0 #G = yiwT xi − 1 + Diiαi
            #step b of algorithm 1
            PG = G 
            if (alpha[i]==0):
                PG = min(G,0)
            if (alpha[i]==u):
                PG = max(G,0)
            #step c
            if PG != 0: 
                ahat = alpha[i]
                alpha[i] = min(max(alpha[i]-G*((y[i]**2)*X[i].dot(X[i])),0),u)
                w = w + ((alpha[i]-ahat)*y[i])*X[i]
    return w

# %%
print(dual_coord_l1(X_train,y,900))
# Out:
# [ 0.03921854  1.46935718  0.93659894  0.5803544  -0.69832627 -1.04619497
#   0.55080124  0.44274586 -0.89881617  1.46131964 -0.33075994  0.03921854
#   6.72152406  0.28778094  0.14918275  0.36798394 -0.1467784  -1.28314678
#  -1.28091468  0.7050631   0.        ]
